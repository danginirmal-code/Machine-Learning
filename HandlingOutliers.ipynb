# %%
import numpy as np
lst_marks=[45,5,6,54,45,3,3,32,43,4,545,6,564,54,34]

# %%
minimum,Q1,median,Q3,maximum=np.quantile(lst_marks,[0,0.25,0.50,0.75,1.0])

# %%
minimum,Q1,median,Q3,maximum
# Out:
# (np.float64(3.0),
#  np.float64(5.5),
#  np.float64(34.0),
#  np.float64(49.5),
#  np.float64(564.0))

# %%
IQR=Q3-Q1
print(IQR)
# Out:
# 44.0

# %%
lower_fence=Q1-1.5*(IQR)
higher_fence=Q3+1.5*(IQR)

# %%
lower_fence
higher_fence
# Out:
# np.float64(115.5)

# %%
import seaborn as sns
sns.boxplot(lst_marks)
